# %%
import pandas as pd

# %%
df1 = pd.read_csv("Deployment.csv")

# %%
df2 = pd.read_csv("articles.csv")

# %%
df3 = pd.read_csv("customers_Final.csv")

# %%
df4 = df1.merge(df2, on='article_id', how='left').merge(df3, on='customer_id', how='left')

# %%
df4
# Out:
#           article_id  product_code_x  customer_id     price  confidence(1)  \
# 0        616598025.0        616598.0     424651.0  0.025407       0.975506
# 1        692449001.0        692449.0     614152.0  0.009475       0.975506
# 2        717490057.0        717490.0     524122.0  0.007610       0.975506
# 3        808569001.0        808569.0     747966.0  0.011847       0.975506
# 4        832298003.0        832298.0      30273.0  0.030492       0.975506
# ...              ...             ...          ...       ...            ...
# 2832973  699426003.0        699426.0     618252.0  0.041949       0.975506
# 2832974  678342002.0        678342.0     779559.0  0.008458       0.975506
# 2832975  882900008.0        882900.0     573207.0  0.067780       0.975506
# 2832976  764624001.0        764624.0     769384.0  0.019949       0.975506
# 2832977  819139001.0        819139.0     304895.0  0.033881       0.975506
#
#          confidence(0)  prediction(sale)  product_code_y  \
# ...

# %%
df4.to_csv('ULTIMO_CSV.csv', index=False)
