# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df1 = pd.read_csv("articles.csv")

# %%
df2 = pd.read_csv("customers.csv")

# %%
df3 = pd.read_csv("test_data.csv")

# %%
df4 = df3.merge(df1, on='article_id', how='left').merge(df2, on='customer_id', how='left')

# %%
#profile = ProfileReport(df4, title = "Merge - Articles, Customers and Test")

# %%
#profile.to_file(output_file = 'output_Merge-Test.html')

# %%
df4.drop(columns=['FN','Active'], inplace=True)

# %%
df4[df4['age'].isna()]
# Out:
#                                                customer_id  article_id  \
# 41       1bd20064db06a874799db47fbf2f86a87d71dcf94149ce...   716552002
# 127      c4e87a803f6714172e300354140b8991fd5defbe19bcf0...   841434001
# 559      734843462f993e3f6ec83dbbbdc9f391a05472e6d62119...   825811004
# 809      3f5ded7a9e55def6c4bd28bc77300a9a03d12eb8269759...   700688001
# 1838     af11cb60ded2beb37de27d51dface913cb7c1ebd5f14b1...   701265003
# ...                                                    ...         ...
# 2869297  3501772938f7f2a514698325c5474cd707a53c8cd5be4e...   562245062
# 2869312  6246e8e40d32d3462a2582b3e21fdc472a51e85ffcffdf...   564310015
# 2869316  533c552a4b6335abecb8e94e8b42eab86e683154d9a2e9...   685816044
# 2869805  a56a1a904d8bbb7ccffcd3f6823adb90f2da3e07040d83...   806241005
# 2869860  38cf747f712442eddfec982801612c52900b2acd478d1b...   758353001
#
#             price  sales_channel_id  product_code  \
# 41       0.050831                 1        716552
# ...

# %%
df4['age'].fillna(df4['age'].median(), inplace=True)
df4[df4['age'].isna()]
# Out:
# Empty DataFrame
# Columns: [customer_id, article_id, price, sales_channel_id, product_code, prod_name, product_type_no, product_type_name, product_group_name, graphical_appearance_no, graphical_appearance_name, colour_group_code, colour_group_name, perceived_colour_value_id, perceived_colour_value_name, perceived_colour_master_id, perceived_colour_master_name, department_no, department_name, index_code, index_name, index_group_no, index_group_name, section_no, section_name, garment_group_no, garment_group_name, detail_desc, club_member_status, fashion_news_frequency, age, postal_code]
# Index: []
#
# [0 rows x 32 columns]

# %%
df4[df4['club_member_status'].isna()]
# Out:
#                                                customer_id  article_id  \
# 63       6d0fced9c20d8be57454b9029b4ac2ee4fe8472d892f20...   824995004
# 111      dd3ac66d57e617122375b3ce3d3ab13b4ed09114d1608d...   643833006
# 691      43ecc4436994c38aac9a4f1bc1ab0600f77c2e0ce6cd6f...   687034024
# 798      33dd1c5ffff1f21618426a18c894ea54bccb902e728791...   573716012
# 2400     0114a45b341dd5230d1e93258f72f8cdd7f6abe69950d4...   741040001
# ...                                                    ...         ...
# 2868318  04beec1434d20a9a149beeb2f2c2cabaae3c63dbed140d...   827968004
# 2868703  062102a6616034704d6c90dd2ea63f6a3120c3a82b9518...   514182003
# 2868773  9bb441e74cccd125be514b6013bd15c7f5fc908ceacd8e...   714379001
# 2869479  cd9942e3b148b07aeb1963285b4c7ef9ff9ebe4e083934...   576050002
# 2869571  ee54d83d9ed8aeb6677068262df4ef34251464d1f326ee...   673677003
#
#             price  sales_channel_id  product_code  \
# 63       0.016932                 2        824995
# ...

# %%
df4['club_member_status'].fillna('ACTIVE', inplace=True)
df4[df4['club_member_status'].isna()]
# Out:
# Empty DataFrame
# Columns: [customer_id, article_id, price, sales_channel_id, product_code, prod_name, product_type_no, product_type_name, product_group_name, graphical_appearance_no, graphical_appearance_name, colour_group_code, colour_group_name, perceived_colour_value_id, perceived_colour_value_name, perceived_colour_master_id, perceived_colour_master_name, department_no, department_name, index_code, index_name, index_group_no, index_group_name, section_no, section_name, garment_group_no, garment_group_name, detail_desc, club_member_status, fashion_news_frequency, age, postal_code]
# Index: []
#
# [0 rows x 32 columns]

# %%
df4[df4['fashion_news_frequency'].isna()]
# Out:
#                                                customer_id  article_id  \
# 383      c625b2de42fc6072ec97d7927d462ea0fad77c28f2b2fb...   754267014
# 395      fff67693cb122cc9a939988a5e2194c044e0881b3f1d5f...   723380001
# 861      6419c54203dac293b1ffb3ea1a89bcaafa987db2f0a379...   432566001
# 868      c3acf54ded2d837254cfaaf2b27f0eb1ae19339be51d39...   677885011
# 1064     a07a59ffba6d885df2223323eb5cc229eca52ef4192328...   780418005
# ...                                                    ...         ...
# 2869369  2153ac83fbb11b37d60ae0eaabc096d7786cb969457656...   187949019
# 2869386  b036e6fe4a9b7fc6982538fdcbcccf9102263d1622af3f...   825811001
# 2869390  4ce693cfaeeff1407564dee0972053e712f72bedc6eff7...   732017005
# 2869739  1f6699ad4cc7290b6c99b6ae22b0293ca718c4012fd4ba...   504154033
# 2869988  613910a1fa615286e0d638e7cf6bded71e07775dc439ff...   673940004
#
#             price  sales_channel_id  product_code                   prod_name  \
# ...

# %%
df4['fashion_news_frequency'].fillna(method ='ffill', inplace=True)
df4[df4['fashion_news_frequency'].isna()]
# Out:
# Empty DataFrame
# Columns: [customer_id, article_id, price, sales_channel_id, product_code, prod_name, product_type_no, product_type_name, product_group_name, graphical_appearance_no, graphical_appearance_name, colour_group_code, colour_group_name, perceived_colour_value_id, perceived_colour_value_name, perceived_colour_master_id, perceived_colour_master_name, department_no, department_name, index_code, index_name, index_group_no, index_group_name, section_no, section_name, garment_group_no, garment_group_name, detail_desc, club_member_status, fashion_news_frequency, age, postal_code]
# Index: []
#
# [0 rows x 32 columns]

# %%
df4[df4['detail_desc'].isna()]
# Out:
#                                                customer_id  article_id  \
# 185      23b6b4d5616ab9d8d973fb3766de342855bb55f90f53ac...   469039019
# 385      d7466a6495afe808eef18dc840fc76d4004413f9e457e9...   637268008
# 569      5414c422ae7ef84eda76f9951c51f666aada59daa64773...   510419004
# 815      3a020aa69df906244cfe55a338169b410244f316aa207f...   684824002
# 1979     b14ad54cf776559705b8356ee29cb810304394349385f7...   685150002
# ...                                                    ...         ...
# 2869070  94ea59da4500e648f997bc156badbd571e074d85fff2f2...   592835001
# 2869160  7093d9aa3ca81223362634ac271b22f6f765dba13e225d...   742916003
# 2869175  bf09cb94b2061eb0da442626b8e25b9293b46d05409e79...   684824003
# 2869319  471261e712ff8cf5a4dd6671e937a8e38cb3fceecb10d9...   426199021
# 2869699  496a2a679b1385dd4d28569ffad6c5c68c5888278438f8...   663518002
#
#             price  sales_channel_id  product_code                   prod_name  \
# ...

# %%
df4['detail_desc'].fillna(method ='ffill', inplace=True)
df4[df4['detail_desc'].isna()]
# Out:
# Empty DataFrame
# Columns: [customer_id, article_id, price, sales_channel_id, product_code, prod_name, product_type_no, product_type_name, product_group_name, graphical_appearance_no, graphical_appearance_name, colour_group_code, colour_group_name, perceived_colour_value_id, perceived_colour_value_name, perceived_colour_master_id, perceived_colour_master_name, department_no, department_name, index_code, index_name, index_group_no, index_group_name, section_no, section_name, garment_group_no, garment_group_name, detail_desc, club_member_status, fashion_news_frequency, age, postal_code]
# Index: []
#
# [0 rows x 32 columns]

# %%
df4 = df4.drop_duplicates(keep='first')

# %%
df4.duplicated().sum()
# Out:
# 0

# %%
df4.dtypes
# Out:
# customer_id                      object
# article_id                        int64
# price                           float64
# sales_channel_id                  int64
# product_code                      int64
# prod_name                        object
# product_type_no                   int64
# product_type_name                object
# product_group_name               object
# graphical_appearance_no           int64
# graphical_appearance_name        object
# colour_group_code                 int64
# colour_group_name                object
# perceived_colour_value_id         int64
# perceived_colour_value_name      object
# perceived_colour_master_id        int64
# perceived_colour_master_name     object
# department_no                     int64
# department_name                  object
# index_code                       object
# index_name                       object
# index_group_no                    int64
# index_group_name                 object
# ...

# %%
df4.drop(columns=['prod_name','product_type_name','graphical_appearance_name','colour_group_name','perceived_colour_value_name','perceived_colour_master_name','department_name','index_group_name','section_name','garment_group_name'], inplace=True)
df4
# Out:
# C:\Users\ricar\AppData\Local\Temp\ipykernel_29652\268533465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop(columns=['prod_name','product_type_name','graphical_appearance_name','colour_group_name','perceived_colour_value_name','perceived_colour_master_name','department_name','index_group_name','section_name','garment_group_name'], inplace=True)
#                                                customer_id  article_id  \
# 0        84de9b53a1f9104d6f4ab511415264ffc37c5d8808fe5b...   616598025
# 1        bfeb1e2504be7a5f3a4277c4f8ef4a7f7f366122d7bd7d...   692449001
# 2        a3e5fda6f79e3036b16edfd021ad4a8375f0239dc355be...   717490057
# 3        e9ed19363db866d72854d218b6061407612d0bb8504fc8...   808569001
# 4        097d7b505a961095c4ca7c20889fb96c7ab6c40e75a0cb...   832298003
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()

df4["change"] = ord_enc.fit_transform(df4[["customer_id"]])
df4 = df4.drop("customer_id", axis=1)
df4.rename(columns = {"change":"customer_id"}, inplace = True)
# Out:
# C:\Users\ricar\AppData\Local\Temp\ipykernel_29652\2410206212.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4["change"] = ord_enc.fit_transform(df4[["customer_id"]])

# %%
df4["change"] = ord_enc.fit_transform(df4[["product_group_name"]])
df4 = df4.drop("product_group_name", axis=1)
df4.rename(columns = {"change":"product_group_name"}, inplace = True)

# %%
df4["change"] = ord_enc.fit_transform(df4[["index_code"]])
df4 = df4.drop("index_code", axis=1)
df4.rename(columns = {"change":"index_code"}, inplace = True)

# %%
df4["change"] = ord_enc.fit_transform(df4[["index_name"]])
df4 = df4.drop("index_name", axis=1)
df4.rename(columns = {"change":"index_name"}, inplace = True)

# %%
df4["change"] = ord_enc.fit_transform(df4[["detail_desc"]])
df4 = df4.drop("detail_desc", axis=1)
df4.rename(columns = {"change":"detail_desc"}, inplace = True)

# %%
df4["change"] = ord_enc.fit_transform(df4[["club_member_status"]])
df4 = df4.drop("club_member_status", axis=1)
df4.rename(columns = {"change":"club_member_status"}, inplace = True)

# %%
df4["change"] = ord_enc.fit_transform(df4[["fashion_news_frequency"]])
df4 = df4.drop("fashion_news_frequency", axis=1)
df4.rename(columns = {"change":"fashion_news_frequency"}, inplace = True)

# %%
df4["change"] = ord_enc.fit_transform(df4[["postal_code"]])
df4 = df4.drop("postal_code", axis=1)
df4.rename(columns = {"change":"postal_code"}, inplace = True)

# %%
df4.dtypes
# Out:
# article_id                      int64
# price                         float64
# sales_channel_id                int64
# product_code                    int64
# product_type_no                 int64
# graphical_appearance_no         int64
# colour_group_code               int64
# perceived_colour_value_id       int64
# perceived_colour_master_id      int64
# department_no                   int64
# index_group_no                  int64
# section_no                      int64
# garment_group_no                int64
# age                           float64
# customer_id                   float64
# product_group_name            float64
# index_code                    float64
# index_name                    float64
# detail_desc                   float64
# club_member_status            float64
# fashion_news_frequency        float64
# postal_code                   float64
# dtype: object

# %%
df4 = df4[["article_id", "product_code", "customer_id", "price"]]
df4
# Out:
#          article_id  product_code  customer_id     price
# 0         616598025        616598     424651.0  0.025407
# 1         692449001        692449     614152.0  0.009475
# 2         717490057        717490     524122.0  0.007610
# 3         808569001        808569     747966.0  0.011847
# 4         832298003        832298      30273.0  0.030492
# ...             ...           ...          ...       ...
# 2869995   699426003        699426     618252.0  0.041949
# 2869996   678342002        678342     779559.0  0.008458
# 2869997   882900008        882900     573207.0  0.067780
# 2869998   764624001        764624     769384.0  0.019949
# 2869999   819139001        819139     304895.0  0.033881
#
# [2832978 rows x 4 columns]

# %%
df4.to_csv('Dataset_Test.csv', index=False)
